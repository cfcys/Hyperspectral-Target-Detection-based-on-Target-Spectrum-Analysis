# %%
from utils import Data
from e_cem import ECEM

# %%
data = Data('hyperspectral_data//san.mat')

# %%
imgshow = [data.img[1,].reshape(data.grt.shape, order='F'),data.img[3,].reshape(data.grt.shape, order='F'), data.grt]

# %%
import matplotlib.pyplot as plt
import math

# %%
k = math.ceil(len(imgshow) / 3) * 100 + 31

# %%
for i in range(len(imgshow)):  # show image
    plt.subplot(k + i)
    plt.axis('off')
    plt.imshow(imgshow[i], cmap='gray')
